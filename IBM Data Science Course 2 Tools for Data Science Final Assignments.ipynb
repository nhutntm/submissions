# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# **Exercise 2: Create markdown cell with title of the notebook**
# # **Data Science Tools and Ecosystem**

# %% [markdown]
# **Exercise 3 - Create a markdown cell for an introduction**
#
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Exercise 4 - Create a markdown cell to list data science languages**
#
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. Scala
# 4. Julia

# %% [markdown]
# **Exercise 5 - Create a markdown cell to list data science libraries**
#
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. Numpy
# 3. Seaborn
# 4. Scikit-learn

# %% [markdown]
# **Exercise 6 - Create a markdown cell with a table of Data Science tools**
#
# | Data Science Tools       |
# |--------------------------|
# | Jupyter Notebooks        |
# | RStudio                  |
# | VS Code with Python      |

# %% [markdown]
# **Exercise 7 - Create a markdown cell introducing arithmetic expression examples**
#
#
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# **Exercise 8 - Create a code cell to multiply and add numbers**

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %% [markdown]
# **Exercise 9 - Create a code cell to convert minutes to hours**

# %%
# This will convert 200 minutes to hours by diving by 60
mins = 200
print(f"The result is: {mins/60} hours or {mins//60} hours and {mins%60} minutes")
# Out:
# The result is: 3.3333333333333335 hours or 3 hours and 20 minutes

# %% [markdown]
# **Exercise 10 - Insert a markdown cell to list Objectives**

# %% [markdown]
# Objectives:
#
#     - Languages used for Data Science
#     - Common libraries for Data Science
#     - Using tools for Data Science such as Jupyter Notebook, and Github

# %% [markdown]
# ## **Author**
# - Nhut Nguyen
